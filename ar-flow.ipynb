# %%
### develop-unit branch of ReactiveMP.jl

# %%
using Revise
using GraphPPL
using Rocket
using ReactiveMP
using Distributions
using Plots
using LinearAlgebra
using Random
using JLD
using Parameters
using Flux
using PositiveFactorizations
import ProgressMeter
# Out:
# ┌ Info: Precompiling ReactiveMP [a194aa59-28ba-4574-a09c-4a745416d6e3]
# └ @ Base loading.jl:1317

# %%
import ReactiveMP.fastcholesky
using PositiveFactorizations

# %%
function ReactiveMP.fastcholesky(mat::AbstractMatrix)
    return cholesky(PositiveFactorizations.Positive, Hermitian(mat))
end

# %%
data_seed, params_seed = 42, 120
# Out:
# (42, 120)

# %%
import ReactiveMP.messageout

# %%
include("helpers/data.jl")
include("helpers/form_constraint.jl")

# %%
melu(x) = clamp(x, tiny, Inf)
# Out:
# melu (generic function with 1 method)

# %%
# order = 1
Y = zeros(3); Y[1] = 1.0;
U = zeros(3); U[2] = 1.0;
H = zeros(3); H[3] = 1.0;

# %%
# Nonlinear MAX model definition
@model [default_factorisation=MeanField()] function nonlinear_max(n, model_flow::FlowModel, params, h_prior, y_prev, u)
    
    dimension = length(h_prior[1])

    # Extract parameters for flow, neural network and Gamma
    del = nr_params(model_flow)
    params_flow = params[1:del]
    params_w = params[end-1:end]
    
    # initialize variables
    h       = randomvar(n)
    hy      = randomvar(n)
    hyu     = randomvar(n)
    θ       = randomvar() where {form_constraint = FixedMarginalConstraint(NormalMeanPrecision(0.0, 1e12))}  
    w       = randomvar() where {form_constraint = FixedMarginalConstraint(GammaShapeRate(melu(params_w[1]), melu(params_w[2])))}
    y       = datavar(Float64, n)

    ar_nodes = Vector{FactorNode}(undef, n)
    y_nodes = Vector{FactorNode}(undef, n)

    y_lat_1 = randomvar(n)
    y_lat_2 = randomvar(n)
    y_lat_3 = randomvar(n)
    
    Ys = [Y*y_prev[i] for i in 1:n]
    Us = [U*u[i] for i in 1:n]

    # create meta for AR
    AR_meta = ARMeta(Univariate, 1, ARsafe())
    # create meta compile flow model
    Flow_meta  = FlowMeta(compile(model_flow, params_flow)) # default: FlowMeta(model, Linearization())
    h_0 ~ NormalMeanPrecision(h_prior[1], h_prior[2])

    θ   ~ NormalMeanPrecision(0.0, 1e12)
    w   ~ GammaShapeRate(melu(params_w[1]), melu(params_w[2]))
    
    h_prev = h_0
    for t in 1:n
        # specify latent state
        ar_nodes[t], h[t] ~ AR(h_prev, θ, w) where {q = q(y, x)q(γ)q(θ), meta = AR_meta}
        hy[t] ~ H*h[t] + Ys[t]
        hyu[t] ~ hy[t] + Us[t]
        y_lat_1[t] ~ Flow(hyu[t]) where { meta = Flow_meta}
        y_lat_2[t] ~ dot(y_lat_1[t], ones(dimension*3))
        y_nodes[t], y[t] ~ NormalMeanPrecision(y_lat_2[t], w)
        h_prev = h[t]
    end

    return h, hy, hyu, θ, w, y_lat_1, y_lat_2, y, y_nodes
end
# Out:
# nonlinear_max (generic function with 1 method)

# %%
function nonlinear_max_inference(observations, observations_prev, controls, model_flow::FlowModel, params; 
                                 h_prior=(0.0, 0.1), vmp_its=10)
    # fetch number of samples
    n = length(observations)

    # define model
    model, (h, hy, hyu, θ, w, y_lat_1, y_lat_2, y, y_nodes) = nonlinear_max(n, model_flow, params, h_prior,
                                                                       observations_prev, controls,
                                                                       options = (limit_stack_depth = 500, ))
    
    h_buffer = Vector{Marginal}(undef, n)
    hy_buffer = Vector{Marginal}(undef, n)
    hyu_buffer = Vector{Marginal}(undef, n)
    θ_buffer = Vector{Marginal}(undef, n)
    y_out_buffer = Vector{AbstractMessage}(undef, n)
    w_buffer = nothing
    
    h_sub = subscribe!(getmarginals(h), (x) -> copyto!(h_buffer, x))
    hy_sub = subscribe!(getmarginals(h), (x) -> copyto!(hy_buffer, x))
    w_sub = subscribe!(getmarginal(w), (x) -> w_buffer = x)
    θ_sub = subscribe!(getmarginal(θ), (x) -> θ_buffer = x)
    y_out_sub = subscribe!(collectLatest(messageout.(ReactiveMP.getinterface.(y_nodes, :out))), 
                                         (x) -> copyto!(y_out_buffer, ReactiveMP.as_message.(x)))
    
    # initialize free energy
    fe_buffer = Vector()
    
    # subscribe
    fe_sub = subscribe!(score(BetheFreeEnergy(), model), (f) -> push!(fe_buffer, f))

    setmarginal!(w, GammaShapeRate(1.0, 1.0))
    setmarginal!(θ, NormalMeanPrecision(0.0, 1.0))
    
    ProgressMeter.@showprogress for _ in 1:vmp_its
        ReactiveMP.update!(y, observations)
    end
    
    # unsubscribe
    unsubscribe!(fe_sub)
    unsubscribe!(h_sub)
    unsubscribe!(w_sub)
    unsubscribe!(θ_sub)
    
    # return the marginal values
    return fe_buffer, h_buffer, hy_buffer, hyu_buffer, w_buffer, y_out_buffer, θ_buffer
    
end
# Out:
# nonlinear_max_inference (generic function with 1 method)

# %%
order_y, order_u, order_h = 2, 2, 2
full_order = order_h + order_y + order_u
Y = zeros(full_order, order_y); Y[1:order_y, 1:order_y] = diageye(order_y);
U = zeros(full_order, order_u); U[order_y+1:order_y+order_u, 1:order_u] = diageye(order_u);
H = zeros(full_order, order_h); H[full_order-order_h+1:full_order, 1:order_h] = diageye(order_h);

# %%
# Nonlinear MAX model definition
@model [default_factorisation=MeanField()] function nonlinear_max_mv(n, model_flow::FlowModel, params, h_prior, y_prev, u, y_order, u_order, h_order)
    
    order = h_order + y_order + u_order

    # Extract parameters for flow, neural network and Gamma
    del = nr_params(model_flow)
    params_flow = params[1:del]
    params_w = params[end-1:end]
    
    # initialize variables
    h       = randomvar(n)
    hy      = randomvar(n)
    hyu     = randomvar(n)
    θ       = randomvar() where {form_constraint = FixedMarginalConstraint(MvNormalMeanPrecision(zeros(h_order), 1e12*diageye(h_order)))}  
    w       = randomvar() where {form_constraint = FixedMarginalConstraint(GammaShapeRate(melu(params_w[1]), melu(params_w[2])))}
    y       = datavar(Float64, n)

    ar_nodes = Vector{FactorNode}(undef, n)
    y_nodes = Vector{FactorNode}(undef, n)

    y_lat_1 = randomvar(n)
    y_lat_2 = randomvar(n)
    y_lat_3 = randomvar(n)
    
    Ys = [Y*y_prev[i] for i in 1:n]
    Us = [U*u[i] for i in 1:n]

    # create meta for AR
    AR_meta = ARMeta(Multivariate, h_order, ARsafe())
    # create meta compile flow model
    Flow_meta  = FlowMeta(compile(model_flow, params_flow)) # default: FlowMeta(model, Linearization())
    h_0 ~ MvNormalMeanPrecision(h_prior[1], h_prior[2])

    θ   ~ MvNormalMeanPrecision(zeros(order_h), 1e12*diageye(order_h))
    w   ~ GammaShapeRate(melu(params_w[1]), melu(params_w[2]))
    
    h_prev = h_0
    for t in 1:n
        # specify latent state
        ar_nodes[t], h[t] ~ AR(h_prev, θ, w) where {q = q(y, x)q(γ)q(θ), meta = AR_meta}
        hy[t] ~ H*h[t] + Ys[t]
        hyu[t] ~ hy[t] + Us[t]
        y_lat_1[t] ~ Flow(hyu[t]) where { meta = Flow_meta}
        y_lat_2[t] ~ dot(y_lat_1[t], ones(order))
        y_nodes[t], y[t] ~ NormalMeanPrecision(y_lat_2[t], w)
        h_prev = h[t]
    end

    return h, hy, hyu, θ, w, y_lat_1, y_lat_2, y, y_nodes
end
# Out:
# nonlinear_max_mv (generic function with 1 method)

# %%
function nonlinear_max_inference_mv(observations, observations_prev, controls, model_flow::FlowModel, params;  
                                    y_order, u_order, h_order,
                                    h_prior=(zeros(h_order), 0.1*diageye(h_order)), vmp_its=10)
    # fetch number of samples
    n = length(observations)

    # define model
    model, (h, hy, hyu, θ, w, y_lat_1, y_lat_2, y, y_nodes) = nonlinear_max_mv(n, model_flow, params, h_prior,
                                                                               observations_prev, controls,
                                                                               y_order, u_order, h_order,
                                                                               options = (limit_stack_depth = 500, ))
    
    h_buffer = Vector{Marginal}(undef, n)
    hy_buffer = Vector{Marginal}(undef, n)
    hyu_buffer = Vector{Marginal}(undef, n)
    θ_buffer = Vector{Marginal}(undef, n)
    y_out_buffer = Vector{AbstractMessage}(undef, n)
    w_buffer = nothing
    
    h_sub = subscribe!(getmarginals(h), (x) -> copyto!(h_buffer, x))
    hy_sub = subscribe!(getmarginals(h), (x) -> copyto!(hy_buffer, x))
    w_sub = subscribe!(getmarginal(w), (x) -> w_buffer = x)
    θ_sub = subscribe!(getmarginal(θ), (x) -> θ_buffer = x)
    y_out_sub = subscribe!(collectLatest(messageout.(ReactiveMP.getinterface.(y_nodes, :out))), 
                                         (x) -> copyto!(y_out_buffer, ReactiveMP.as_message.(x)))
    
    # initialize free energy
    fe_buffer = Vector()
    
    # subscribe
    fe_sub = subscribe!(score(BetheFreeEnergy(), model), (f) -> push!(fe_buffer, f))

    setmarginal!(w, GammaShapeRate(1.0, 1.0))
    setmarginal!(θ, MvNormalMeanPrecision(zeros(h_order), diageye(h_order)))
    
    ProgressMeter.@showprogress for _ in 1:vmp_its
        ReactiveMP.update!(y, observations)
    end
    
    # unsubscribe
    unsubscribe!(fe_sub)
    unsubscribe!(h_sub)
    unsubscribe!(w_sub)
    unsubscribe!(θ_sub)
    
    # return the marginal values
    return fe_buffer, h_buffer, hy_buffer, hyu_buffer, w_buffer, y_out_buffer, θ_buffer
    
end
# Out:
# nonlinear_max_inference_mv (generic function with 1 method)

# %%
# specify flow model
dimension = full_order
model_flow = FlowModel(dimension,
    (
        AdditiveCouplingLayer(PlanarFlow()), # defaults to AdditiveCouplingLayer(PlanarFlow(); permute=true)
        AdditiveCouplingLayer(PlanarFlow()),
        AdditiveCouplingLayer(PlanarFlow())
    )
);

# %%
function ssm(series, order)
    inputs = [reverse!(series[1:order])]
    outputs = [series[order + 1]]
    for x in series[order+2:end]
        push!(inputs, vcat(outputs[end], inputs[end])[1:end-1])
        push!(outputs, x)
    end
    return inputs, outputs
end
# Out:
# ssm (generic function with 1 method)

# %%
Random.seed!(data_seed)

n_samples = 1000
u = 3 .* sin.(collect(1:n_samples+10))
y_lat, y_obs, h_gen = generate_data(n_samples, narx, Dict(:order_y=>order_y, :order_u=>order_u, :order_e=>order_h),
                                                     Dict(:er_var=>1e-2, :u=>u));

# %%
observations_prev, observations = ssm(y_obs, order_y)
controls = ssm(u, order_u)[1]
# Out:
# 1008-element Vector{Vector{Float64}}:
#  [2.727892280477045, 2.5244129544236893]
#  [0.4233600241796016, 2.727892280477045]
#  [-2.2704074859237844, 0.4233600241796016]
#  [-2.8767728239894153, -2.2704074859237844]
#  [-0.8382464945967776, -2.8767728239894153]
#  [1.9709597961563672, -0.8382464945967776]
#  [2.9680747398701453, 1.9709597961563672]
#  [1.2363554557252698, 2.9680747398701453]
#  [-1.6320633326681093, 1.2363554557252698]
#  [-2.9999706196521103, -1.6320633326681093]
#  [-1.609718754001305, -2.9999706196521103]
#  [1.2605011104799226, -1.609718754001305]
#  [2.971822067084611, 1.2605011104799226]
#  ⋮
#  [-2.5664194559090623, -2.6939024414938535]
#  [-0.07938225821119238, -2.5664194559090623]
#  [2.4806386215960075, -0.07938225821119238]
#  [2.7599717927589653, 2.4806386215960075]
#  [0.5017996259213775, 2.7599717927589653]
#  [-2.2177248028207854, 0.5017996259213775]
#  [-2.8982832754114494, -2.2177248028207854]
#  [-0.9141734707069559, -2.8982832754114494]
#  [1.9104232070385518, -0.9141734707069559]
#  [2.9785855986008283, 1.9104232070385518]
#  [1.3082501272607694, 2.9785855986008283]
#  [-1.5648844777782662, 1.3082501272607694]

# %%
train_size = 80
X_train, Y_train, U_train = observations_prev[1:train_size], observations[1:train_size], controls[1:train_size]
X_test, Y_test, U_test = observations_prev[train_size+1:end], observations[train_size+1:end], controls[train_size+1:end];

# %%
from, to = 1, 80
plot(y_obs, xlims=(1, train_size))
plot!(Y_train, xlims=(from, to), xlabel="T", ylabel="value", legend=false)

# %%
Random.seed!(params_seed)

flow_param_len = nr_params(model_flow)
model_params = [randn(flow_param_len); [0.1, 1.0]]
# Out:
# 47-element Vector{Float64}:
#  -0.9194589934298287
#   1.0117762040383562
#  -0.008656271104353946
#  -1.7061637862602859
#  -0.38240881051735015
#   1.142903405886922
#   1.5994173837327952
#  -0.6606269914068376
#   1.7280026513115074
#  -0.13897835603040912
#  -0.6737809225295219
#   0.04878749639808164
#   1.67258141660508
#   ⋮
#  -1.2688151069939353
#   0.5442892692759611
#   0.9515135579177358
#  -2.2502731970794416
#  -1.8241177727907605
#   0.5887138745053259
#   0.6765822621496003
#   0.29873821278434554
#   0.35665768910493706
#  -0.5512200526575644
#   0.1
#   1.0

# %%
# fe_, h_, hy_, hyu_, w_, y_out_, θ_ = nonlinear_max_inference(Y_train, X_train, U_train, model_flow, model_params, vmp_its=10);

# %%
fe_, h_, hy_, hyu_, w_, y_out_, θ_ = nonlinear_max_inference_mv(Y_train, X_train, U_train, model_flow, model_params, y_order=order_y, u_order=order_u, h_order=order_h, vmp_its=10);
# Out:
# AssertionError: Half-edge has been found: hyu. To terminate half-edges 'Uninformative' node can be used.
#
# Stacktrace:
#   [1] (::ReactiveMP.var"#660#665")(randomvar::RandomVariable)
#     @ ReactiveMP ~/.julia/dev/ReactiveMP/src/model.jl:101
#   [2] filter!(f::ReactiveMP.var"#660#665", a::Vector{RandomVariable})
#     @ Base ./array.jl:2552
#   [3] activate!(model::Model{ModelOptions{EmptyPipelineStage, MeanField, ReactiveMP.LimitStackScheduler}})
#     @ ReactiveMP ~/.julia/dev/ReactiveMP/src/model.jl:100
#   [4] macro expansion
#     @ ~/.julia/dev/GraphPPL/src/GraphPPL.jl:324 [inlined]
#   [5] macro expansion
#     @ ./In[62]:51 [inlined]
#   [6] nonlinear_max_mv(n::Int64, model_flow::FlowModel{6, Tuple{ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}, ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}, ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}}}, params::Vector{Float64}, h_prior::Tuple{Vector{Float64}, Matrix{Float64}}, y_prev::Vector{Vector{Float64}}, u::Vector{Vector{Float64}}, y_order::Int64, u_order::Int64, h_order::Int64; options::NamedTuple{(:limit_stack_depth,), Tuple{Int64}})
#     @ Main ~/.julia/dev/GraphPPL/src/GraphPPL.jl:334
#   [7] nonlinear_max_inference_mv(observations::Vector{Float64}, observations_prev::Vector{Vector{Float64}}, controls::Vector{Vector{Float64}}, model_flow::FlowModel{6, Tuple{ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}, ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}, ReactiveMP.AdditiveCouplingLayerEmpty{NTuple{5, ReactiveMP.PlanarFlowEmpty{1}}}, PermutationLayer{Int64}}}, params::Vector{Float64}; y_order::Int64, u_order::Int64, h_order::Int64, h_prior::Tuple{Vector{Float64}, Matrix{Float64}}, vmp_its::Int64)
#     @ Main ./In[63]:8
#   [8] top-level scope
#     @ In[72]:1
#   [9] eval
#     @ ./boot.jl:360 [inlined]
#  [10] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094

# %%
plot(mean.(y_out_), ribbon=sqrt.(cov.(y_out_)))
plot!(Y_train, xlims=(1, 100))
# Out:
# UndefVarError: y_out_ not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[20]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
gr()
plot(fe_, label="FE = $(fe_[end])")
# Out:
# UndefVarError: fe_ not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[21]:2
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
# Optimization function
function FE(params)
    fe, h, hy, hyu, w, y_out, θ = nonlinear_max_inference(Y_train, X_train, U_train, model_flow, params, 
                                                 h_prior=(0.0, 0.1), 
                                                 vmp_its=1)
    return fe[end]
end;

# %%
FE(model_params)
# Out:
# UndefVarError: nonlinear_max_inference not defined
#
# Stacktrace:
#  [1] FE(params::Vector{Float64})
#    @ Main ./In[22]:3
#  [2] top-level scope
#    @ In[23]:1
#  [3] eval
#    @ ./boot.jl:360 [inlined]
#  [4] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
# unpack if you don't want to run Optim
@unpack inf_params = JLD.load("dump/f_dataseed_$(data_seed)_paramsseed_$(params_seed).jld")

# %%
using Optim
res = optimize(FE, model_params, LBFGS(), Optim.Options(g_tol = 1e-12, iterations = 2000, store_trace = true, show_trace = true, show_every=10), autodiff=:forward)

# %%
inf_params = Optim.minimizer(res)
# Out:
# 20-element Vector{Float64}:
#   12.488736062296322
#    7.000912737467863
#   25.769154392361262
#    5.710119881356676
#    2.1893233210995935
#   -4.208211500192602
#   63.37841476648121
#   -0.043663879913668595
#   -0.08305055092042823
#  118.24729726446215
#   -0.024993819173217132
#    0.04997912674370987
#    2.7449479685090146
#  -18.863772886852438
#  -24.92203304609955
#   12.635112959930149
#   -0.49743721957737713
#    8.706254283943903
#   61.283067907113235
#   22.651217630426764

# %%
using JLD
JLD.save("dump/f_dataseed_$(data_seed)_paramsseed_$(params_seed).jld", "inf_params", inf_params)

# %%
FE(inf_params)
# Out:
# 607.6025622851298

# %%
inf_params = Optim.minimizer(res)
fe_, h_, hy_, hyu_, w_, y_out_, θ_ = nonlinear_max_inference(Y_train, X_train, U_train, model_flow, inf_params, vmp_its=100);
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:08

# %%
plot(fe_inf[1:end], label="FE = $(fe_inf[end])")

# %%
from, to = 100, 150
# Out:
# (100, 150)

# %%
my, vy = mean.(y_out_), cov.(y_out_)
plot(Y_train, xlims=(from, to), label="real signal")
plot!(my, ribbon=sqrt.(vy), label="output messages")

# %%
mh, vh = mean.(h_inf), cov.(h_inf)
plot(h_gen)
plot!(first.(mh), ribbon=sqrt.(first.(vh)), xlims=(from, to))

# %% [markdown]
# ### KF-like prediction

# %%
function transition(γ, order)
    V = zeros(order, order)
    V[1] = 1/γ
    return V
end

function shift(dim)
    S = Matrix{Float64}(I, dim, dim)
    for i in dim:-1:2
           S[i,:] = S[i-1, :]
    end
    S[1, :] = zeros(dim)
    return S
end
# Out:
# shift (generic function with 1 method)

# %%
# Nonlinear MAX model definition
@model [default_factorisation=MeanField()] function nonlinear_max_prediction(model_flow::FlowModel, params, w, h_prior, y_prev, u)
    
    dimension = length(h_prior[1])

#     A = shift(dimension) # transition matrix
#     V = transition(w, dimension)

    # initialize variables
    y_pred   = datavar(Float64)
    
    Ys = Y*y_prev
    Us = U*u
    
    del = nr_params(model_flow)
    params_flow = params[1:del]
    params_f = params[del+1:end-2]
    params_w = params[end-1:end]

    h_0 = randomvar() where {form_constraint = FixedMarginalConstraint(NormalMeanPrecision(h_prior[1], h_prior[2]))}

    # compile flow model
    Flow_meta  = FlowMeta(compile(model_flow, params_flow)) # default: FlowMeta(model, Linearization())
    h_0 ~ NormalMeanPrecision(h_prior[1], h_prior[2])
    
#     Ah ~ A*h_0
    h ~ NormalMeanVariance(h_0, w) where {q = q(h_0, h)q(w)}
    
    hy ~ H*h + Ys
    hyu ~ hy + Us
    
    y_lat_1 ~ Flow(hyu) where { meta = Flow_meta, q = FullFactorisation() }
    
    y_lat_2 ~ dot(y_lat_1, ones(dimension*3))

    y_node, y ~ NormalMeanPrecision(y_lat_2, w) where { q = q(y, y_lat_2)q(w)}
    
    y_pred ~ NormalMeanPrecision(y, 1e-12)
    
    return h, h_0, y_lat_1, y_lat_2, y, y_node, y_pred
end
# Out:
# nonlinear_max_prediction (generic function with 2 methods)

# %%
function nonlinear_max_prediction(observation_prev::T, control::T, model_flow::FlowModel, params; 
                                  h_prior=(ones(2), diageye(2)), w=1.0, vmp_its = 50) where T<:Float64

    # define model
    model, (h, h_0, y_lat_1, y_lat_2, y, y_node, y_pred) = nonlinear_max_prediction(model_flow, params, w, h_prior,
                                                                                    observation_prev, control,
                                                                                    options = (limit_stack_depth = 500, ))
    
    h_buffer = nothing
    h0_buffer = nothing
    y_out_buffer = nothing
    y_pred_buffer = nothing
    
    h_sub = subscribe!(getmarginal(h), (x) -> h_buffer = x)
    h0_sub = subscribe!(getmarginal(h_0), (x) -> h0_buffer = x)
    y_pred_sub = subscribe!(getmarginal(y), (x) -> y_pred_buffer = x)

    fe_buffer = Vector()
    
    # subscribe
    fe_sub = subscribe!(score(BetheFreeEnergy(), model), (f) -> push!(fe_buffer, f))
    
    setmarginal!(y, NormalMeanPrecision(0.0, 1.0))
    
    for _ in 1:vmp_its
        ReactiveMP.update!(y_pred, 0.0)
    end
    
    # return the marginal values
    return fe_buffer, h_buffer, h0_buffer, y_pred_buffer
    
end
# Out:
# nonlinear_max_prediction (generic function with 2 methods)

# %%
predictions = []
h_prev = (mean(h_[end]), precision(h_[end]))
ŵ = mean(w_)
for i in 1:length(X_test)
    fe, h, h_0, y_pred = nonlinear_max_prediction(X_test[i], U_test[i], model_flow, inf_params, h_prior=h_prev, w=ŵ, vmp_its=10)
    push!(predictions, y_pred)
    _, h_inf, _, _, _ = nonlinear_max_inference([Y_test[i]], [X_test[i]], [U_test[i]], model_flow, inf_params, h_prior=h_prev, vmp_its=10);
    h_prev = (mean.(h_inf)[1], precision.(h_inf)[1])
end

# %%
mx, vx = mean.(predictions), cov.(predictions)
# Out:
# ([0.26440739079758485, 0.24548969233134443, -0.7239730913981637, -0.1495896461636676, -0.13612909642861146, 0.5061598028881746, 0.4590718430244768, 0.016440731487532712, -0.7593513460708371, -0.5125777613226852  …  -0.28740062724642645, -0.06036096736928794, 0.18862689691257142, 0.09015036373949, 0.23066268482109156, 0.4898995577749155, -0.03710119430978007, -0.00755669016287774, -0.03686622605192634, 0.5599457211637408], [0.5238914200050959, 0.5458275918535671, 0.46243597663885594, 0.37722207079784936, 0.4161802039164093, 0.40919998879668107, 0.49504564978476273, 0.5576719417389973, 0.48801623661323607, 0.398454823283158  …  0.42250504244900666, 0.41270796637365487, 0.38885315271196524, 0.44857043971676447, 0.537058677503939, 0.5292680849665309, 0.44365689390576163, 0.39717236700995867, 0.40992461457684587, 0.42564906880645076])

# %%
test_from, test_to = 150, 200
# Out:
# (150, 200)

# %%
plot(Y_test, label="real")
plot!(mx, ribbon=sqrt.(vx), xlims=(test_from, test_to), label="predicted")
